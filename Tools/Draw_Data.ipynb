# %% [markdown]
# # Draw the data in seconds
#
# Hello, I am **[Dipam Soni](https://flowcv.me/dipamsoni)** and here is my portfolio website where you can find more information about me.
#
# You can reach me through **[LinkedIn](https://www.linkedin.com/in/dipam-soni-276aa8207)**
#
# Post Link: **[GitHub](https://github.com/dipamsoni/Data-Science/tree/main/Tools/Draw_Data.ipynb)**
#
# Spread 💙, Be 😃, Go with the flow 🎈.
#
# Love & Regards from Dipam.

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import seaborn as sns

from matplotlib_inline.backend_inline import set_matplotlib_formats
set_matplotlib_formats('svg')

# %%
from drawdata import draw_scatter
draw_scatter()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/scatter.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df = pd.read_csv("../_Datasets/Created_Data.csv")
sns.relplot(data=df, x='x', y='y', hue='z')
