# %% [markdown]
# ### Skimpy is a tool for summarizing Pandas dataframes that generates a richer statistical summary than the describe() method in a single line of code. The summary is grouped by datatypes for efficient analysis, and it can be used from the command line as well. Additional information can be found in the comments. Therefore, to supercharge the describe method in Pandas, one can use Skimpy.

# %%
from skimpy import skim
import pandas as pd

# %%
df = pd.read_csv("crypto.csv")

# %%
df
# Out:
#              slug symbol       name        date  ranknow      open      high  \
# 0         bitcoin    BTC    Bitcoin   4/28/2013        1    135.30    135.98
# 1         bitcoin    BTC    Bitcoin   4/29/2013        1    134.44    147.49
# 2         bitcoin    BTC    Bitcoin   4/30/2013        1    144.00    146.93
# 3         bitcoin    BTC    Bitcoin    5/1/2013        1    139.00    139.89
# 4         bitcoin    BTC    Bitcoin    5/2/2013        1    116.38    125.60
# ...           ...    ...        ...         ...      ...       ...       ...
# 942292  project-x  NANOX  Project-X  11/26/2018     1727  22424.60  23049.30
# 942293  project-x  NANOX  Project-X  11/27/2018     1727  20711.90  23742.10
# 942294  project-x  NANOX  Project-X  11/28/2018     1727  23320.90  25235.10
# 942295  project-x  NANOX  Project-X  11/29/2018     1727  24543.53  24582.47
# 942296  project-x  NANOX  Project-X  11/30/2018     1727  22872.09  23086.98
#
#              low     close  volume        market  close_ratio   spread
# 0         132.10    134.21     0.0  1.488567e+09       0.5438     3.88
# 1         134.00    144.54     0.0  1.603769e+09       0.7813    13.49
# 2         134.05    139.00     0.0  1.542813e+09       0.3843    12.88
# 3         107.72    116.99     0.0  1.298955e+09       0.2882    32.17
# 4          92.28    105.21     0.0  1.168517e+09       0.3881    33.32
# ...          ...       ...     ...           ...          ...      ...
# 942292  17607.50  20724.80   143.0  1.622000e+03       0.5728  5441.80
# 942293  19292.90  23298.70   637.0  1.823000e+03       0.9003  4449.20
# 942294  19888.10  24442.70    49.0  1.913000e+03       0.8518  5347.00
# 942295  21457.95  22839.44   153.0  1.788000e+03       0.4421  3124.52
# 942296  19040.91  21136.72   125.0  1.654000e+03       0.5180  4046.07
#
# [942297 rows x 13 columns]

# %%
skim(df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 942297 │ │ float64     │ 8     │                                                          │
# │ │ Number of columns │ 13     │ │ string      │ 4     │                                                          │
# │ └───────────────────┴────────┘ │ int32       │ 1     │                                                          │
# │                                └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━┳━━━━━┳━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━┓  │
# │ ┃ column_name  ┃ NA  ┃ NA %  ┃ mean       ┃ sd          ┃ p0      ┃ p25    ┃ p75     ┃ p100         ┃ hist   ┃  │
# │ ┡━━━━━━━━━━━━━━╇━━━━━╇━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━┩  │
# │ │ ranknow      │   0 │     0 │       1000 │         590 │       1 │    460 │    1500 │         2100 │ ▆▅▅▆█▃ │  │
# │ │ open         │   0 │     0 │        350 │       13000 │ 2.5e-09 │ 0.0023 │    0.23 │      2300000 │   █    │  │
# │ │ high         │   0 │     0 │        410 │       16000 │ 3.2e-09 │ 0.0026 │    0.25 │      2900000 │   █    │  │
# │ │ low          │   0 │     0 │        300 │       11000 │  2.5e-1 │  0.002 │     0.2 │      2000000 │   █    │  │
# │ │ close        │   0 │     0 │        350 │       13000 │    2e-1 │ 0.0023 │    0.23 │      2300000 │   █    │  │
# │ │ volume       │   0 │     0 │    8700000 │   180000000 │       0 │    180 │  120000 │  24000000000 │   █    │  │
# │ │ market       │   0 │     0 │  170000000 │  3600000000 │       0 │  30000 │ 6900000 │ 330000000000 │   █    │  │
# │ │ close_ratio  │   0 │     0 │       0.46 │        0.33 │      -1 │   0.16 │    0.75 │            1 │    █▅▆ │  │
# │ │ spread       │   0 │     0 │        110 │        6800 │       0 │      0 │    0.03 │      1800000 │   █    │  │
# │ └──────────────┴─────┴───────┴────────────┴─────────────┴─────────┴────────┴─────────┴──────────────┴────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name               ┃ NA      ┃ NA %       ┃ words per row                ┃ total words              ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ slug                      │       0 │          0 │                            1 │                   940000 │  │
# │ │ symbol                    │       0 │          0 │                            1 │                   940000 │  │
# │ │ name                      │       0 │          0 │                            1 │                   940000 │  │
# │ │ date                      │       0 │          0 │                            1 │                   940000 │  │
# │ └───────────────────────────┴─────────┴────────────┴──────────────────────────────┴──────────────────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %% [markdown]
# ### To supercharge the describe method in Pandas, one can use Summarytools, a simple EDA tool that generates a standardized and comprehensive data summary in a single line of code. This summary includes column statistics, frequency, distribution chart, and missing stats. Additional information can be found in the comments.

# %%
from summarytools import dfSummary

# %%
dfSummary(df)
# Out:
# <style type="text/css">
# #T_8c1cd thead>tr>th {
#   text-align: left;
# }
# #T_8c1cd_row0_col0, #T_8c1cd_row1_col0, #T_8c1cd_row2_col0, #T_8c1cd_row3_col0, #T_8c1cd_row4_col0, #T_8c1cd_row5_col0, #T_8c1cd_row6_col0, #T_8c1cd_row7_col0, #T_8c1cd_row8_col0, #T_8c1cd_row9_col0, #T_8c1cd_row10_col0, #T_8c1cd_row11_col0, #T_8c1cd_row12_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_8c1cd_row0_col1, #T_8c1cd_row1_col1, #T_8c1cd_row2_col1, #T_8c1cd_row3_col1, #T_8c1cd_row4_col1, #T_8c1cd_row5_col1, #T_8c1cd_row6_col1, #T_8c1cd_row7_col1, #T_8c1cd_row8_col1, #T_8c1cd_row9_col1, #T_8c1cd_row10_col1, #T_8c1cd_row11_col1, #T_8c1cd_row12_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_8c1cd_row0_col2, #T_8c1cd_row1_col2, #T_8c1cd_row2_col2, #T_8c1cd_row3_col2, #T_8c1cd_row4_col2, #T_8c1cd_row5_col2, #T_8c1cd_row6_col2, #T_8c1cd_row7_col2, #T_8c1cd_row8_col2, #T_8c1cd_row9_col2, #T_8c1cd_row10_col2, #T_8c1cd_row11_col2, #T_8c1cd_row12_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_8c1cd_row0_col3, #T_8c1cd_row1_col3, #T_8c1cd_row2_col3, #T_8c1cd_row3_col3, #T_8c1cd_row4_col3, #T_8c1cd_row5_col3, #T_8c1cd_row6_col3, #T_8c1cd_row7_col3, #T_8c1cd_row8_col3, #T_8c1cd_row9_col3, #T_8c1cd_row10_col3, #T_8c1cd_row11_col3, #T_8c1cd_row12_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_8c1cd_row0_col4, #T_8c1cd_row1_col4, #T_8c1cd_row2_col4, #T_8c1cd_row3_col4, #T_8c1cd_row4_col4, #T_8c1cd_row5_col4, #T_8c1cd_row6_col4, #T_8c1cd_row7_col4, #T_8c1cd_row8_col4, #T_8c1cd_row9_col4, #T_8c1cd_row10_col4, #T_8c1cd_row11_col4, #T_8c1cd_row12_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_8c1cd_row0_col5, #T_8c1cd_row1_col5, #T_8c1cd_row2_col5, #T_8c1cd_row3_col5, #T_8c1cd_row4_col5, #T_8c1cd_row5_col5, #T_8c1cd_row6_col5, #T_8c1cd_row7_col5, #T_8c1cd_row8_col5, #T_8c1cd_row9_col5, #T_8c1cd_row10_col5, #T_8c1cd_row11_col5, #T_8c1cd_row12_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_8c1cd">
#   <caption><strong>Data Frame Summary</strong><br>_<br>Dimensions: 942,297 x 13<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_8c1cd_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_8c1cd_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_8c1cd_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_8c1cd_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_8c1cd_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_8c1cd_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8c1cd_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_8c1cd_row0_col1" class="data row0 col1" ><strong>slug</strong><br>[object]</td>
#       <td id="T_8c1cd_row0_col2" class="data row0 col2" >1. bitcoin<br>2. litecoin<br>3. namecoin<br>4. novacoin<br>5. peercoin<br>6. feathercoin<br>7. terracoin<br>8. bitbar<br>9. worldcoin<br>10. digitalcoin<br>11. other</td>
#       <td id="T_8c1cd_row0_col3" class="data row0 col3" >2,042 (0.2%)<br>2,042 (0.2%)<br>2,042 (0.2%)<br>2,041 (0.2%)<br>2,041 (0.2%)<br>2,037 (0.2%)<br>2,027 (0.2%)<br>2,014 (0.2%)<br>2,003 (0.2%)<br>1,999 (0.2%)<br>922,009 (97.8%)</td>
#       <td id="T_8c1cd_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_8c1cd_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_8c1cd_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_8c1cd_row1_col1" class="data row1 col1" ><strong>symbol</strong><br>[object]</td>
#       <td id="T_8c1cd_row1_col2" class="data row1 col2" >1. BITS<br>2. PXC<br>3. BTB<br>4. BTM<br>5. LTC<br>6. NMC<br>7. BTC<br>8. NVC<br>9. PPC<br>10. FTC<br>11. other</td>
#       <td id="T_8c1cd_row1_col3" class="data row1 col3" >3,189 (0.3%)<br>2,123 (0.2%)<br>2,049 (0.2%)<br>2,043 (0.2%)<br>2,042 (0.2%)<br>2,042 (0.2%)<br>2,042 (0.2%)<br>2,041 (0.2%)<br>2,041 (0.2%)<br>2,037 (0.2%)<br>920,648 (97.7%)</td>
#       <td id="T_8c1cd_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_8c1cd_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_8c1cd_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_8c1cd_row2_col1" class="data row2 col1" ><strong>name</strong><br>[object]</td>
#       <td id="T_8c1cd_row2_col2" class="data row2 col2" >1. Bitcoin<br>2. Litecoin<br>3. Namecoin<br>4. Novacoin<br>5. Peercoin<br>6. Feathercoin<br>7. Terracoin<br>8. BitBar<br>9. WorldCoin<br>10. Digitalcoin<br>11. other</td>
#       <td id="T_8c1cd_row2_col3" class="data row2 col3" >2,042 (0.2%)<br>2,042 (0.2%)<br>2,042 (0.2%)<br>2,041 (0.2%)<br>2,041 (0.2%)<br>2,037 (0.2%)<br>2,027 (0.2%)<br>2,014 (0.2%)<br>2,003 (0.2%)<br>1,999 (0.2%)<br>922,009 (97.8%)</td>
#       <td id="T_8c1cd_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_8c1cd_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_8c1cd_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_8c1cd_row3_col1" class="data row3 col1" ><strong>date</strong><br>[object]</td>
#       <td id="T_8c1cd_row3_col2" class="data row3 col2" >1. 11/29/2018<br>2. 11/28/2018<br>3. 11/27/2018<br>4. 11/24/2018<br>5. 11/21/2018<br>6. 11/25/2018<br>7. 11/26/2018<br>8. 11/22/2018<br>9. 11/23/2018<br>10. 11/20/2018<br>11. other</td>
#       <td id="T_8c1cd_row3_col3" class="data row3 col3" >2,071 (0.2%)<br>2,071 (0.2%)<br>2,067 (0.2%)<br>2,064 (0.2%)<br>2,064 (0.2%)<br>2,064 (0.2%)<br>2,064 (0.2%)<br>2,064 (0.2%)<br>2,064 (0.2%)<br>2,062 (0.2%)<br>921,642 (97.8%)</td>
#       <td id="T_8c1cd_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_8c1cd_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_8c1cd_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_8c1cd_row4_col1" class="data row4 col1" ><strong>ranknow</strong><br>[int64]</td>
#       <td id="T_8c1cd_row4_col2" class="data row4 col2" >Mean (sd) : 1000.2 (587.6)<br>min < med < max:<br>1.0 < 1072.0 < 2072.0<br>IQR (CV) : 1019.0 (1.7)</td>
#       <td id="T_8c1cd_row4_col3" class="data row4 col3" >2,068 distinct values</td>
#       <td id="T_8c1cd_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_8c1cd_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_8c1cd_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_8c1cd_row5_col1" class="data row5 col1" ><strong>open</strong><br>[float64]</td>
#       <td id="T_8c1cd_row5_col2" class="data row5 col2" >Mean (sd) : 348.4 (13184.4)<br>min < med < max:<br>0.0 < 0.0 < 2298390.0<br>IQR (CV) : 0.2 (0.0)</td>
#       <td id="T_8c1cd_row5_col3" class="data row5 col3" >266,140 distinct values</td>
#       <td id="T_8c1cd_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_8c1cd_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_8c1cd_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_8c1cd_row6_col1" class="data row6 col1" ><strong>high</strong><br>[float64]</td>
#       <td id="T_8c1cd_row6_col2" class="data row6 col2" >Mean (sd) : 408.6 (16163.9)<br>min < med < max:<br>0.0 < 0.0 < 2926100.0<br>IQR (CV) : 0.2 (0.0)</td>
#       <td id="T_8c1cd_row6_col3" class="data row6 col3" >269,676 distinct values</td>
#       <td id="T_8c1cd_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_8c1cd_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_8c1cd_row7_col0" class="da
